# %%
from pybit.unified_trading import HTTP
import pandas as pd
import pandas_ta as ta
import numpy as np
import matplotlib.pyplot as plt

# %%
session = HTTP(
  api_key='Tslbb2SPI4RpjbKvJZ',
  api_secret='TlkxskklUioua3q4Gyj3xkBT69WIOzojfcn0'
)

kline = session.get_kline(symbol='OPUSDT', interval='5', limit=50)['result']['list']

# %%
from asdf import get_dataframe
df = get_dataframe(kline)

# %%
# calculate MACD values
df.ta.macd(close='close', fast=12, slow=26, append=True)
df
# Out:
# /tmp/ipykernel_6028/2124912084.py:2: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   df.ta.macd(close='close', fast=12, slow=26, append=True)
#                 open  highest  lowest   close    volume      turnover  \
# 1.710330e+12  4.4913   4.4925  4.4738  4.4828   76633.8  3.434678e+05
# 1.710330e+12  4.4828   4.4908  4.4774  4.4790   31373.7  1.407150e+05
# 1.710330e+12  4.4790   4.4849  4.4631  4.4718  107190.5  4.791991e+05
# 1.710331e+12  4.4718   4.4801  4.4671  4.4794   51927.2  2.323144e+05
# 1.710331e+12  4.4794   4.4864  4.4788  4.4840   19707.0  8.835327e+04
# 1.710331e+12  4.4840   4.4948  4.4836  4.4889   42406.6  1.903381e+05
# 1.710332e+12  4.4889   4.4908  4.4856  4.4874   19739.3  8.859375e+04
# 1.710332e+12  4.4874   4.4933  4.4820  4.4899   19033.7  8.537953e+04
# ...

# %%
df['EMA200'] = ta.ema(df['close'], length=20)
df
# Out:
# /tmp/ipykernel_6028/3354266868.py:1: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   df['EMA200'] = ta.ema(df['close'], length=20)
#                 open  highest  lowest   close    volume      turnover  \
# 1.710330e+12  4.4913   4.4925  4.4738  4.4828   76633.8  3.434678e+05
# 1.710330e+12  4.4828   4.4908  4.4774  4.4790   31373.7  1.407150e+05
# 1.710330e+12  4.4790   4.4849  4.4631  4.4718  107190.5  4.791991e+05
# 1.710331e+12  4.4718   4.4801  4.4671  4.4794   51927.2  2.323144e+05
# 1.710331e+12  4.4794   4.4864  4.4788  4.4840   19707.0  8.835327e+04
# 1.710331e+12  4.4840   4.4948  4.4836  4.4889   42406.6  1.903381e+05
# 1.710332e+12  4.4889   4.4908  4.4856  4.4874   19739.3  8.859375e+04
# 1.710332e+12  4.4874   4.4933  4.4820  4.4899   19033.7  8.537953e+04
# ...

# %%
plt.plot(df['MACDs_12_26_9'], label='signal', color='red')
plt.plot(df['MACD_12_26_9'], label='MACD', color='green')
plt.plot(df['MACDh_12_26_9'], label='asdf', color='blue')
plt.legend()
plt.show()

# %%
plt.plot(df['close'], label='close', color='red')
plt.plot(df['EMA200'], label='EMA', color='blue')
plt.legend()
plt.show()
